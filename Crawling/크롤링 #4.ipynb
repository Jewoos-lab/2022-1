# %%
# 라이브러리 불러오기
import requests
import bs4

# %%
# URL 주소 입력 및 HTML 받아오기
url = "https://browse.gmarket.co.kr/search?keyword=마스크"
raw = requests.get(url)

# %%
# BeautifulSoup 클래스 객체 생성
html = bs4.BeautifulSoup(raw.text, 'html.parser')

# %%
# 데이터를 감싸는 큰 틀 추출
box = html.find('div', {'class' : 'section__module-wrap', 'module-design-id' : '15'})

# %%
# 각 상품 추출
items = box.find_all('div', {"class" : 'box__item-container'})
print(len(items))
# Out:
# 100

# %%
# 각 상품의 이름과 가격을 추출

for item in items:
  title = item.find('span', {'class' : 'text__item'})
  price = item.find('strong', {'class' : 'text__value'})
  print("이름 : ", title.text)
  print('가격 : ', price.text)
  print()
# Out:
# 이름 :   식약처인증 국산 위즈윈 덴탈마스크 50매 일회용 비말
# 가격 :  7,500
#
# 이름 :   뉴케어 입체마스크(KF-AD)비말차단용 25매(5매입x5개)
# 가격 :  14,900
#
# 이름 :   KF94 100%국내 에어블링 황사 마스크(대형) 100매
# 가격 :  35,000
#
# 이름 :   KF94 국내생산 100매 화이트50 블랙50 혼합 황사마스크
# 가격 :  13,770
#
# 이름 :   CLA 슬림핏 새부리형 25매 컬러마스크 중형 다크브라운
# 가격 :  17,250
#
# 이름 :   KF94 한마음 국내산 황사마스크 개별포장 대형 100매
# 가격 :  14,900
#
# 이름 :   새부리형 KF94 국내생산 100매 화이트50 블랙50 혼합
# 가격 :  21,200
#
# 이름 :   100매입/입체형/초소형/소형/중형/특대형마스크
# 가격 :  12,900
#
# 이름 :   더나은 KF94 새부리형 일회용 마스크 대형 화이트100매
# 가격 :  25,900
#
# 이름 :   국내생산 2D 새부리형 4중 컬러 마스크 대형 소형
# 가격 :  23,160
#
# 이름 :   국산 KF80 3중 황사 미세먼지차단 보건용마스크 대형
# 가격 :  19,720
#
# 이름 :   국산 3중 구조 일회용 마스크 대형 화이트 50매
# 가격 :  7,900
#
# 이름 :   KF94 새부리형 대형 마스크 일회용 황사미세먼지 1매
# 가격 :  590
#
# 이름 :   A3 2020 초특대형 블랙마스크 숨쉬기편한마스크 100매
# 가격 :  26,100
#
# 이름 :   국산 다샵 클린 KF-AD 비말차단 마스크 화이트 100매
# 가격 :  12,870
#
# 이름 :   아르떼 새부리형 마스크 KF94 100매 화이트 개별포장
# 가격 :  26,900
#
# 이름 :   아르떼 KF94 국산 컬러 마스크 새부리형 개별포장
# 가격 :  28,900
#
# 이름 :   케이엔에스 코블로킹데일리 KF-AD 3중필터 마스크50매
# 가격 :  5,000
#
# 이름 :   몽키키 3D 정품KF80필터 피부자극제로 대형/1매 라일락
# 가격 :  390
#
# 이름 :   KF94 블랙100%국산에어블링 황사방역마스크 대형 100매
# 가격 :  35,000
#
# 이름 :   힐메이드 KF94 성인용 화이트 마스크 100매 당일발송
# 가격 :  47,000
#
# 이름 :   바이오엠 KF-AD 비말차단덴탈마스크 1box 50개
# 가격 :  6,000
#
# 이름 :   바이오엠 KF-AD 비말차단덴탈마스크 1box 100매
# 가격 :  12,000
#
# 이름 :   바이오 셀프케어 KF-AD 비말차단 마스크 100매
# 가격 :  15,900
#
# 이름 :   멜트블로운 3중필터 일회용 마스크 블랙 대형 50매
# 가격 :  3,800
#
# 이름 :   CLA KF94 새부리형 50매 마스크 대형 화이트
# 가격 :  24,500
#
# 이름 :   에버뉴크린 새부리형마스크 KF94 (그레이/대형) 100입
# 가격 :  26,900
#
# 이름 :   에버뉴크린 새부리형마스크 KF94 (블랙/대형) 100입
# 가격 :  26,900
#
# 이름 :   인가드 국산 KF94 황사 미세먼지 마스크 대형 100매
# 가격 :  26,900
#
# 이름 :   생활마스크 KF94 소형 100매 어린이 선물세트 포장
# 가격 :  22,900
#
# 이름 :   에버뉴크린 새부리형마스크 KF94 (화이트/대형) 100입
# 가격 :  26,900
#
# 이름 :   지원정 새부리형 KF94 중형 마스크 100매 비말차단
# 가격 :  23,070
#
# 이름 :   아르떼 새부리형 마스크 KF94 100매 화이트 개별포장
# 가격 :  26,900
#
# 이름 :   새부리형 마스크 KF94 의약외품 개별포장 블랙 100매
# 가격 :  26,900
#
# 이름 :   에버뉴크린 새부리형마스크 KF94 (그레이/대형) 100입
# 가격 :  26,900
#
# 이름 :   크리넥스 kf80 입체형 마스크 화이트 소형10Px4개
# 가격 :  24,900
#
# 이름 :   KF94 국내생산 100매 화이트50 블랙50 혼합 황사마스크
# 가격 :  13,770
#
# 이름 :   KF94 국내생산 100매 황사마스크 화이트 (10x10)
# 가격 :  13,770
#
# 이름 :   새부리형 KF94 100매 국내생산 황사마스크 화이트10x10
# 가격 :  16,650
#
# 이름 :   참존 굿매너 마스크 KF94  대형 흰색 100매
# 가격 :  29,900
#
# 이름 :   새부리형 KF94 대형 마스크 100매 지원정 비말차단
# 가격 :  19,900
#
# 이름 :   KF94 국내생산 100매 황사마스크 블랙 (10x10)
# 가격 :  13,770
#
# 이름 :   새부리형 KF94 국내생산 100매 화이트50 블랙50 혼합
# 가격 :  21,200
#
# 이름 :   에어데이즈 KF94 새부리형 국산 마스크 대형 50매
# 가격 :  26,900
#
# 이름 :   KF94 새부리형 에이앤피 컬러 마스크 혼합 중형 100매
# 가격 :  29,800
#
# 이름 :   국산 KF94 마스크 대형 화이트 일반형 200매
# 가격 :  23,880
#
# 이름 :   새부리형 KF94 소형 100매 화이트50 블랙50 혼합 10x10
# 가격 :  21,200
#
# 이름 :   국산 KF94 블랙 마스크 비티 100매 개별포장 파격할인
# 가격 :  17,900
#
# 이름 :   인가드 국산 KF94 황사 미세먼지 마스크 대형 100매
# 가격 :  26,900
#
# 이름 :   kf94 입체형마스크 화이트 대형1Px40개(한박스)
# 가격 :  26,900
#
# 이름 :   인가드 국산 KF94 황사 미세먼지 마스크 대형 100매
# 가격 :  26,900
#
# 이름 :   KF94 새부리형 컬러 마스크 중형 베이지 그레이 100매
# 가격 :  29,800
#
# 이름 :   국산 새부리형 KF94 마스크 100매 블랙 대형
# 가격 :  20,900
#
# 이름 :   맘하트 KF94 덴탈마스크 일회용비말차단마스크50매
# 가격 :  8,900
#
# 이름 :   지원정KF94 중형 화이트100매(25매X4)새부리형마스크
# 가격 :  20,900
#
# 이름 :   국산 3중 비말차단 마스크 300매 KF-AD MB필터 마스크
# 가격 :  18,510
#
# 이름 :   KF94 비움 에코플러스 새부리형마스크 블랙 100매
# 가격 :  19,900
#
# 이름 :   생활마스크 KF94 소형 100매 어린이 선물세트 포장
# 가격 :  22,900
#
# 이름 :   KF94 비움 에코플러스 새부리형마스크 화이트 100매
# 가격 :  19,900
#
# 이름 :   KF94 비움 에코플러스 국산마스크 화이트50매+블랙50매
# 가격 :  19,900
#
# 이름 :   KF94 비움 에코프로 국산마스크 화이트50매+블랙50매
# 가격 :  19,900
#
# 이름 :   착한가격 싹퍼드림 KF94 마스크 100매 대형 개별포장
# 가격 :  18,800
#
# 이름 :   국산 KF94 마스크 대형 흰색 100매+100매 (총 200매)
# 가격 :  23,900
#
# 이름 :   KF94 비움 에코프로 국산 새부리형마스크 블랙 100매
# 가격 :  19,900
#
# 이름 :   에이앤피 새부리형 KF94 마스크 대형 120매 (화이트30  블랙30  다크그레이30  베이지30)
# 가격 :  36,020
#
# 이름 :   지원정 새부리형 KF94 중형 마스크 100매 비말차단
# 가격 :  23,070
#
# 이름 :   에버프레쉬 소형 KF94마스크 새부리형 50매 화이트
# 가격 :  27,900
#
# 이름 :   덴탈형 KF94마스크 화이트 국내생산 (50매입X2ea)
# 가격 :  21,180
#
# 이름 :    네퓨어   화이트  뉴 황사방역용마스크 KF94 대형 70매
# 가격 :  45,900
#
# 이름 :   에어데이즈 KF94 마스크 새부리형 대형 50매 황사
# 가격 :  26,500
#
# 이름 :   순수숨 KF94 새부리형 국산 일회용 마스크 흰색 100매
# 가격 :  26,900
#
# 이름 :   KF94 100%국내 에어블링 황사 마스크(대형) 100매
# 가격 :  35,000
#
# 이름 :   국산 특별가 Kf94 대형수 마스크 100매/비말차단 일회
# 가격 :  19,900
#
# 이름 :   KF94 미달이 순풍마스크 100매 흰색L 개별포장 성인
# 가격 :  29,900
#
# 이름 :   전구성KF94  299원 호 컬러 마스크 150매(핑크/베이지/그레이/흰/검)+스트랩 1종
# 가격 :  42,510
#
# 이름 :   에이앤피 새부리형 KF94 마스크 중형 120매 (화이트20/블랙20/다크그레이20/베이지20/핑크20/옐로우20)
# 가격 :  36,020
#
# 이름 :   KF94 마스크 100매 대형 개별포장 착한가격 닥터제로
# 가격 :  17,900
#
# 이름 :   에어데이즈 KF94 중형 새부리형 마스크 50매 화이트
# 가격 :  26,500
#
# 이름 :   새부리형 KF94 100매 국내생산 황사마스크 블랙 10x10
# 가격 :  17,880
#
# 이름 :   바이오 셀프케어 KF-AD 비말차단 마스크 100매
# 가격 :  15,900
#
# 이름 :   숨쉬기 귀 편한 일회용 컬러 블랙 덴탈 마스크 100매
# 가격 :  14,900
#
# 이름 :   지원정KF94 중형 블랙100매(25매X4) 새부리형마스크
# 가격 :  24,900
#
# 이름 :   KF94 새부리형 컬러 마스크 중형 블랙 그레이 100매
# 가격 :  29,800
#
# 이름 :   KF94 인증 소형 중형 마스크 50매
# 가격 :  22,900
#
# 이름 :   국산 KF94 마스크 소형 100매 어린이 유아
# 가격 :  17,900
#
# 이름 :   퓨어라이프 KF94 새부리형 마스크 대형 100매 화이트
# 가격 :  28,900
#
# 이름 :   아이리스 새부리형 황사 마스크 중형 100매 KF94 국산
# 가격 :  26,900
#
# 이름 :   국산 새부리형 일회용 마스크 이유 성인용 블랙 100매
# 가격 :  10,900
#
# 이름 :   국산 다샵 클린 KF-AD 비말차단 마스크 화이트 100매
# 가격 :  12,870
#
# 이름 :   스윗홈 데일리 KF94 마스크 새부리형 100매 화이트
# 가격 :  29,900
#
# 이름 :   국산 KF94 마스크 대형 블랙 100매+100매 (총 200매)
# 가격 :  24,900
#
# 이름 :   블루인더스 블루본 마스크 KF80 소형 화이트 50매
# 가격 :  26,500
#
# 이름 :   KF94 새부리형 컬러 마스크 중형 베이지 블랙 100매
# 가격 :  29,800
#
# 이름 :   지원정 블랙 새부리형 KF94 중형 마스크 100매 가을용
# 가격 :  26,900
#
# 이름 :   KF94 새부리형 컬러 마스크 대형 그레이 블랙 100매
# 가격 :  29,800
#
# 이름 :   스틸가드 KF94 마스크 대형 100매 화이트 새부리형 2D
# 가격 :  28,340
#
# 이름 :   더나은 KF94 새부리형 일회용 마스크 대형 화이트100매
# 가격 :  25,900
#
# 이름 :   CLA KF94 새부리형 50매 마스크 대형 화이트
# 가격 :  24,500
#
# 이름 :   블루인더스 블루본 마스크 KF94 소형 화이트 50매
# 가격 :  27,900
#
# 이름 :   KF94 비움 에코프로 국산 새부리형마스크 화이트 100매
# 가격 :  19,900

# %%
import requests
import bs4

while True:
    keyword = input("검색을 원하는 키워드를 입력하세요. ( 0을 입력하면 종료 )")
    if keyword == "0":
        break

    URL = "https://browse.gmarket.co.kr/search?keyword=" + keyword
    raw = requests.get(URL)
    html = bs4.BeautifulSoup(raw.text, 'html.parser')
    box = html.find('div', {'class' : 'section__module-wrap', 'module-design-id' : '15'})
    items = box.find_all('div', {"class" : 'box__item-container'})

    # 기존 : G마켓의 마스크 상품 정보
    print("< G마켓의", keyword, "상품 정보 >")
    for item in items[:10]:
        title = item.find('span', {'class' : 'text__item'})
        price = item.find('strong', {'class' : 'text__value'})
        print("이름 : ", title.text)
        print('가격 : ', price.text)
        print()
# Out:
# 검색을 원하는 키워드를 입력하세요. ( 0을 입력하면 종료 )코로나
# < G마켓의 코로나 상품 정보 >
# 이름 :   세계미래보고서 2021 (포스트 코로나 특별판)
# 가격 :  16,020
#
# 이름 :   두번째 지구는 없다(언어 천재 타일러가 말하는 코로나이후의 위기)
# 가격 :  12,600
#
# 이름 :   순간의 두려움 매일의 기적(코로나19 안나의집 275일간의기록)
# 가격 :  10,800
#
# 이름 :   코로나방역 발열측정패치 일회용 체온계스티커 20개입
# 가격 :  8,400
#
# 이름 :   빅 체인지(코로나19 이후 미래 시나리오)
# 가격 :  15,120
#
# 이름 :   코로나 사피엔스(문명의 대전환 대한민국 대표 석학 6인이 신인류의 미래를 말한다)
# 가격 :  13,500
#
# 이름 :   래피젠 코로나 검사 자가 진단키트 20개입 개별포장
# 가격 :  87,000
#
# 이름 :   SD바이오센서 코로나 자가 검사 진단키트 2매입 x6개 +
# 가격 :  95,040
#
# 이름 :   SD바이오센서 코로나 검사 자가진단키트 1개입
# 가격 :  6,800
#
# 이름 :   SD바이오센서 코로나 검사 자가진단키트 10개입
# 가격 :  77,330
#
# 검색을 원하는 키워드를 입력하세요. ( 0을 입력하면 종료 )0

# %%
import requests
from bs4 import BeautifulSoup

keyword = input("뉴스 검색 키워드: ")
count = 0

for page in range(1, 11):
    news_url = 'https://search.hankyung.com/apps.frm/search.news?query=' + keyword + '&page=' + str(page)
    raw = requests.get(news_url)

    soup = BeautifulSoup(raw.text, 'html.parser')

    box = soup.find('ul', {'class' : 'article'})
    all_title = box.find_all('em', {'class': 'tit'})

    for title in all_title:
        count += 1
        t = title.text
        print(count, '-', t.strip())
# Out:
# 뉴스 검색 키워드: 코로나
# 1 - 북한, 중국 이어 러시아와도 '단계적 교역 회복' 논의
# 2 - 인제군, 소상공인 1인당 최대 200만원씩 긴급경영지원금 지급
# 3 - [올림픽] 일본 피겨대표팀 코치, 코로나 확진…베이징 입성 연기
# 4 - 민주 "추경 최소 35조로 확대…15일전 반드시 처리"
# 5 - 오미크론 변이가 우세종으로...들썩대는 진단키트株
# 6 - 제주 사랑의 온도탑 106.4도…41억3천만원 모금
# 7 - "어디로 가라는건지"…동네병원 코로나 검사 첫날 '혼선'
# 8 - 용띠 아시아 무용수들의 무대 '드래곤즈' 내달 부산 공연
# 9 - 일본, 확진자 동거가족 자가격리 최장 17일→7일 단축
# 10 - 올여름 보령 대천해수욕장 7월 2일·무창포 9일 개장
# 11 - 올여름 보령 대천해수욕장 7월 2일·무창포 9일 개장
# 12 - 제주, 설 연휴 주간 확진자 2.7배 껑충…하루 최대 500명 전망
# 13 - 승자는 누구?…대선 후보 첫 4자토론 관전포인트 [조미현의 국회 삐뚤게 보기]
# 14 - 보컬그룹 노을, 오는 12일 수원서 데뷔 20주년 콘서트
# 15 - [올림픽] '평창 금메달' 스웨덴 여자컬링 대표팀 '코로나 확진' 비상
# 16 - 동네병원 코로나 검사, 첫날부터 혼선…병원명단도 공개 안돼
# 17 - 항공여객 코로나19 명암…국제선 78% 줄고 국내선은 역대 최대
# 18 - 2년째 취소 창녕 3·1민속문화제, 올해는 일단 연기
# 19 - 부산, 1천280명 확진…사흘 연속 최다 기록
# 20 - 키움 야시엘 푸이그, 입국…'악동' 포스 대신 하트 인사(종합)
# 21 - 카카오뱅크 체크카드, 월 최대 4만 4천원 돌려준다
# 22 - 유치원 교원 자격에 보건·영양교사도
# 23 - 오세정 서울대 총장 "교수 정원 합리화 방안 마련 계획"
# 24 - 시몬스 새 브랜드 캠페인은 '치유' 메시지 담긴 디지털아트
# 25 - [단독] 이준X강한나 '붉은 단심' 스태프 코로나 확진, 오늘(3일) 촬영 취소
# 26 - 작년에 잘나갔는데 올해는 우울...힘 빠진 엔터株의 전망은
# 27 - '코로나 봉쇄국' 뉴질랜드 10월까지 국경 완전 개방(종합)
# 28 - 대전 어린이집 필요경비 한도 작년 수준 동결…36만1천900원
# 29 - 제주항공 지상조업 자회사 JAS, 4년간 13만1천여편 조업업무 수행
# 30 - 중국 정부 고문 "미중 우발적 군사충돌 위험 높아"
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-185264879f79> in <module>()
#       7 for page in range(1, 11):
#       8     news_url = 'https://search.hankyung.com/apps.frm/search.news?query=' + keyword + '&page=' + str(page)
# ----> 9     raw = requests.get(news_url)
#      10
#      11     soup = BeautifulSoup(raw.text, 'html.parser')
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ⭐정리하기⭐
#
# ​
#
# ✔ BeautifulSoup 라이브러리를 사용하여 HTML 코드로 변환
#
# ✔ for문을 사용하여 기사제목 수집
#
# ✔ input()으로 키워드 입력받기
